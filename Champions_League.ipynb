# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("Sampiyonlar Ligi 55-16.csv")

# %%
df
# Out:
#            Stage                  Round Group                     Date  \
# 0     Qualifying  Qual. Round 1 | Leg 1   NaN  (Tue) 15 Jul 2008 (W28)
# 1     Qualifying  Qual. Round 1 | Leg 1   NaN  (Tue) 15 Jul 2008 (W28)
# 2     Qualifying  Qual. Round 1 | Leg 1   NaN  (Tue) 15 Jul 2008 (W28)
# 3     Qualifying  Qual. Round 1 | Leg 1   NaN  (Tue) 15 Jul 2008 (W28)
# 4     Qualifying  Qual. Round 1 | Leg 1   NaN  (Tue) 15 Jul 2008 (W28)
# ...          ...                    ...   ...                      ...
# 6549         NaN     Semifinals | Leg 1   NaN   (Wed) 6 Apr 1983 (W14)
# 6550         NaN     Semifinals | Leg 1   NaN   (Wed) 6 Apr 1983 (W14)
# 6551         NaN     Semifinals | Leg 2   NaN  (Wed) 20 Apr 1983 (W16)
# 6552         NaN     Semifinals | Leg 2   NaN  (Wed) 20 Apr 1983 (W16)
# 6553         NaN                  Final   NaN  (Wed) 25 May 1983 (W21)
#
#                               Team 1   FT   HT                     Team 2  \
# ...

# %%
df.head()
# Out:
#         Stage                  Round Group                     Date  \
# 0  Qualifying  Qual. Round 1 | Leg 1   NaN  (Tue) 15 Jul 2008 (W28)
# 1  Qualifying  Qual. Round 1 | Leg 1   NaN  (Tue) 15 Jul 2008 (W28)
# 2  Qualifying  Qual. Round 1 | Leg 1   NaN  (Tue) 15 Jul 2008 (W28)
# 3  Qualifying  Qual. Round 1 | Leg 1   NaN  (Tue) 15 Jul 2008 (W28)
# 4  Qualifying  Qual. Round 1 | Leg 1   NaN  (Tue) 15 Jul 2008 (W28)
#
#                            Team 1   FT   HT                     Team 2  ∑FT  \
# 0        Inter Baku PIK › AZE (1)  0-0  0-0       Rabotnicki › MKD (1)  NaN
# 1  Anorthosis Famagusta › CYP (1)  1-0  0-0           Pyunik › ARM (1)  NaN
# 2          BATE Borisov › BLR (1)  2-0  0-0  Valur Reykjavik › ISL (1)  NaN
# 3        Tampere United › FIN (1)  2-1  0-0        Buducnost › MNE (1)  NaN
# 4         Dinamo Tirana › ALB (1)  0-2  0-0       FK Modrica › BIH (1)  NaN
#
#     ET    P Comments    Adj Date  Year              Home Team Home Team Ctry  \
# ...

# %%
df["Year"].sort_values()
# Out:
# 2992    1955
# 2991    1955
# 2990    1955
# 2989    1955
# 2988    1955
#         ...
# 4487    2016
# 4485    2016
# 4513    2016
# 4498    2016
# 4512    2016
# Name: Year, Length: 6554, dtype: int64

# %%
df.sort_values("Year",inplace=True)

# %%
df.tail()
# Out:
#          Stage                Round Group                     Date  \
# 4487  Knockout  Round of 16 | Leg 1   NaN   (Wed) 17 Feb 2016 (W7)
# 4485  Knockout  Round of 16 | Leg 1   NaN   (Tue) 16 Feb 2016 (W7)
# 4513  Knockout                Final   NaN  (Sat) 28 May 2016 (W21)
# 4498  Knockout  Round of 16 | Leg 2   NaN  (Tue) 15 Mar 2016 (W11)
# 4512  Knockout   Semifinals | Leg 2   NaN   (Wed) 4 May 2016 (W18)
#
#                              Team 1       FT   HT  \
# 4487             KAA Gent › BEL (7)      2-3  0-1
# 4485  Paris Saint-Germain › FRA (7)      2-1  1-1
# 4513      Real Madrid CF › ESP (13)  1-1 (*)  1-0
# 4498   Manchester City FC › ENG (8)      0-0  0-0
# 4512      Real Madrid CF › ESP (12)      1-0  1-0
#
#                              Team 2         ∑FT            ET           P  \
# 4487        VfL Wolfsburg › GER (7)         NaN           NaN         NaN
# 4485           Chelsea FC › ENG (7)         NaN           NaN         NaN
# ...

# %%
df = df[df["Round"].str.contains("Final")]

# %%
df = df[["Round","Team 1","FT","HT","Team 2","ET","P","Year"]]

# %%
df
# Out:
#       Round                     Team 1       FT   HT  \
# 3005  Final   Real Madrid CF › ESP (7)      4-3  0-0
# 3469  Final   Real Madrid CF › ESP (8)      2-0  0-0
# 5402  Final   Real Madrid CF › ESP (7)  2-2 (*)  0-0
# 5837  Final   Real Madrid CF › ESP (8)      2-0  0-0
# 1641  Final   Real Madrid CF › ESP (7)      7-3  0-0
# ...     ...                        ...      ...  ...
# 3425  Final      Chelsea FC › ENG (13)  1-1 (*)  0-0
# 1931  Final  Bayern München › GER (13)      2-1  0-0
# 6288  Final  Real Madrid CF › ESP (13)  1-1 (*)  0-0
# 664   Final    FC Barcelona › ESP (13)      3-1  0-0
# 4513  Final  Real Madrid CF › ESP (13)  1-1 (*)  1-0
#
#                                   Team 2            ET           P  Year
# 3005               Stade Reims › FRA (7)           NaN         NaN  1956
# 3469            ACF Fiorentina › ITA (7)           NaN         NaN  1957
# 5402                 AC Milan › ITA (10)  3-2 (a.e.t.)         NaN  1958
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#                Round                           Team 1       FT   HT  \
# 3005           Final         Real Madrid CF › ESP (7)      4-3  0-0
# 3469           Final         Real Madrid CF › ESP (8)      2-0  0-0
# 5402           Final         Real Madrid CF › ESP (7)  2-2 (*)  0-0
# 5837           Final         Real Madrid CF › ESP (8)      2-0  0-0
# 1641           Final         Real Madrid CF › ESP (7)      7-3  0-0
# 5453           Final             SL Benfica › POR (9)      3-2  0-0
# 2255           Final             SL Benfica › POR (7)      5-3  0-0
# 5896           Final               AC Milan › ITA (9)      2-1  0-0
# 2316           Final         Internazionale › ITA (9)      3-1  0-0
# 727            Final         Internazionale › ITA (7)      1-0  0-0
# 5705           Final         Real Madrid CF › ESP (9)      2-1  0-0
# 4091           Final              Celtic FC › SCO (9)      2-1  0-0
# 5354           Final   Manchester United FC › ENG (9)  1-1 (*)  0-0
# ...

# %%
df.reset_index(drop = True,inplace=True)

# %%
df["Team 1"] = df["Team 1"].apply(lambda x:x.split("›")[0])

df["Team 2"] = df["Team 2"].apply(lambda x:x.split("›")[0])

# %%
df
# Out:
#              Round                 Team 1       FT   HT  \
# 0            Final        Real Madrid CF       4-3  0-0
# 1            Final        Real Madrid CF       2-0  0-0
# 2            Final        Real Madrid CF   2-2 (*)  0-0
# 3            Final        Real Madrid CF       2-0  0-0
# 4            Final        Real Madrid CF       7-3  0-0
# 5            Final            SL Benfica       3-2  0-0
# 6            Final            SL Benfica       5-3  0-0
# 7            Final              AC Milan       2-1  0-0
# 8            Final        Internazionale       3-1  0-0
# 9            Final        Internazionale       1-0  0-0
# 10           Final        Real Madrid CF       2-1  0-0
# 11           Final             Celtic FC       2-1  0-0
# 12           Final  Manchester United FC   1-1 (*)  0-0
# 13           Final              AC Milan       4-0  0-0
# 14           Final   Feyenoord Rotterdam   1-1 (*)  0-0
# 15           Final              AFC Ajax       2-0  0-0
# ...

# %%
df["Year"].value_counts()[df["Year"].value_counts()>1]
# Out:
# 1974    2
# Name: Year, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Round   62 non-null     object
#  1   Team 1  62 non-null     object
#  2   FT      62 non-null     object
#  3   HT      62 non-null     object
#  4   Team 2  62 non-null     object
#  5   ET      16 non-null     object
#  6   P       11 non-null     object
#  7   Year    62 non-null     int64
# dtypes: int64(1), object(7)
# memory usage: 4.0+ KB

# %%
df[df["Round"] == "Final | Replay"]["Year"]
# Out:
# 18    1974
# Name: Year, dtype: int64

# %%
df[df["Year"]==1974]
# Out:
#              Round           Team 1   FT   HT            Team 2   ET    P  \
# 18  Final | Replay  Bayern München   4-0  0-0  Atletico Madrid   NaN  NaN
# 19           Final  Bayern München   1-1  0-0  Atletico Madrid   NaN  NaN
#
#     Year
# 18  1974
# 19  1974

# %%
df["FT"].loc[18]
# Out:
# '4-0'

# %%
df["ET"].loc[19] = df["FT"].loc[18]
# Out:
# C:\Users\potar\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df["ET"].loc[19]
# Out:
# '4-0'

# %%
df
# Out:
#              Round                 Team 1       FT   HT  \
# 0            Final        Real Madrid CF       4-3  0-0
# 1            Final        Real Madrid CF       2-0  0-0
# 2            Final        Real Madrid CF   2-2 (*)  0-0
# 3            Final        Real Madrid CF       2-0  0-0
# 4            Final        Real Madrid CF       7-3  0-0
# 5            Final            SL Benfica       3-2  0-0
# 6            Final            SL Benfica       5-3  0-0
# 7            Final              AC Milan       2-1  0-0
# 8            Final        Internazionale       3-1  0-0
# 9            Final        Internazionale       1-0  0-0
# 10           Final        Real Madrid CF       2-1  0-0
# 11           Final             Celtic FC       2-1  0-0
# 12           Final  Manchester United FC   1-1 (*)  0-0
# 13           Final              AC Milan       4-0  0-0
# 14           Final   Feyenoord Rotterdam   1-1 (*)  0-0
# 15           Final              AFC Ajax       2-0  0-0
# ...

# %%
df = df.drop(18)

# %%
df
# Out:
#     Round                 Team 1       FT   HT                     Team 2  \
# 0   Final        Real Madrid CF       4-3  0-0               Stade Reims
# 1   Final        Real Madrid CF       2-0  0-0            ACF Fiorentina
# 2   Final        Real Madrid CF   2-2 (*)  0-0                  AC Milan
# 3   Final        Real Madrid CF       2-0  0-0               Stade Reims
# 4   Final        Real Madrid CF       7-3  0-0  Frankfurter SG Eintracht
# 5   Final            SL Benfica       3-2  0-0              FC Barcelona
# 6   Final            SL Benfica       5-3  0-0            Real Madrid CF
# 7   Final              AC Milan       2-1  0-0                SL Benfica
# 8   Final        Internazionale       3-1  0-0            Real Madrid CF
# 9   Final        Internazionale       1-0  0-0                SL Benfica
# 10  Final        Real Madrid CF       2-1  0-0         Partizan Belgrade
# 11  Final             Celtic FC       2-1  0-0            Internazionale
# ...

# %%
df = df.reset_index(drop = True)

# %%
df
# Out:
#     Round                 Team 1       FT   HT                     Team 2  \
# 0   Final        Real Madrid CF       4-3  0-0               Stade Reims
# 1   Final        Real Madrid CF       2-0  0-0            ACF Fiorentina
# 2   Final        Real Madrid CF   2-2 (*)  0-0                  AC Milan
# 3   Final        Real Madrid CF       2-0  0-0               Stade Reims
# 4   Final        Real Madrid CF       7-3  0-0  Frankfurter SG Eintracht
# 5   Final            SL Benfica       3-2  0-0              FC Barcelona
# 6   Final            SL Benfica       5-3  0-0            Real Madrid CF
# 7   Final              AC Milan       2-1  0-0                SL Benfica
# 8   Final        Internazionale       3-1  0-0            Real Madrid CF
# 9   Final        Internazionale       1-0  0-0                SL Benfica
# 10  Final        Real Madrid CF       2-1  0-0         Partizan Belgrade
# 11  Final             Celtic FC       2-1  0-0            Internazionale
# ...

# %%
df["FT"] = df["FT"].str.strip("()*")

# %%
df
# Out:
#     Round                 Team 1    FT   HT                     Team 2  \
# 0   Final        Real Madrid CF    4-3  0-0               Stade Reims
# 1   Final        Real Madrid CF    2-0  0-0            ACF Fiorentina
# 2   Final        Real Madrid CF   2-2   0-0                  AC Milan
# 3   Final        Real Madrid CF    2-0  0-0               Stade Reims
# 4   Final        Real Madrid CF    7-3  0-0  Frankfurter SG Eintracht
# 5   Final            SL Benfica    3-2  0-0              FC Barcelona
# 6   Final            SL Benfica    5-3  0-0            Real Madrid CF
# 7   Final              AC Milan    2-1  0-0                SL Benfica
# 8   Final        Internazionale    3-1  0-0            Real Madrid CF
# 9   Final        Internazionale    1-0  0-0                SL Benfica
# 10  Final        Real Madrid CF    2-1  0-0         Partizan Belgrade
# 11  Final             Celtic FC    2-1  0-0            Internazionale
# ...

# %%
df["Team1FT"] = df["FT"].apply(lambda x : x.split("-")[0])

# %%
df["Team2FT"] = df["FT"].apply(lambda x : x.split("-")[1])

# %%
df
# Out:
#     Round                 Team 1    FT   HT                     Team 2  \
# 0   Final        Real Madrid CF    4-3  0-0               Stade Reims
# 1   Final        Real Madrid CF    2-0  0-0            ACF Fiorentina
# 2   Final        Real Madrid CF   2-2   0-0                  AC Milan
# 3   Final        Real Madrid CF    2-0  0-0               Stade Reims
# 4   Final        Real Madrid CF    7-3  0-0  Frankfurter SG Eintracht
# 5   Final            SL Benfica    3-2  0-0              FC Barcelona
# 6   Final            SL Benfica    5-3  0-0            Real Madrid CF
# 7   Final              AC Milan    2-1  0-0                SL Benfica
# 8   Final        Internazionale    3-1  0-0            Real Madrid CF
# 9   Final        Internazionale    1-0  0-0                SL Benfica
# 10  Final        Real Madrid CF    2-1  0-0         Partizan Belgrade
# 11  Final             Celtic FC    2-1  0-0            Internazionale
# ...

# %%
df.drop("HT",axis=1,inplace=True)

# %%
df
# Out:
#     Round                 Team 1    FT                     Team 2  \
# 0   Final        Real Madrid CF    4-3               Stade Reims
# 1   Final        Real Madrid CF    2-0            ACF Fiorentina
# 2   Final        Real Madrid CF   2-2                   AC Milan
# 3   Final        Real Madrid CF    2-0               Stade Reims
# 4   Final        Real Madrid CF    7-3  Frankfurter SG Eintracht
# 5   Final            SL Benfica    3-2              FC Barcelona
# 6   Final            SL Benfica    5-3            Real Madrid CF
# 7   Final              AC Milan    2-1                SL Benfica
# 8   Final        Internazionale    3-1            Real Madrid CF
# 9   Final        Internazionale    1-0                SL Benfica
# 10  Final        Real Madrid CF    2-1         Partizan Belgrade
# 11  Final             Celtic FC    2-1            Internazionale
# 12  Final  Manchester United FC   1-1                 SL Benfica
# ...

# %%
df[["ET","P"]] = df[["ET","P"]].fillna(value="0-0")

# %%
df
# Out:
#     Round                 Team 1    FT                     Team 2  \
# 0   Final        Real Madrid CF    4-3               Stade Reims
# 1   Final        Real Madrid CF    2-0            ACF Fiorentina
# 2   Final        Real Madrid CF   2-2                   AC Milan
# 3   Final        Real Madrid CF    2-0               Stade Reims
# 4   Final        Real Madrid CF    7-3  Frankfurter SG Eintracht
# 5   Final            SL Benfica    3-2              FC Barcelona
# 6   Final            SL Benfica    5-3            Real Madrid CF
# 7   Final              AC Milan    2-1                SL Benfica
# 8   Final        Internazionale    3-1            Real Madrid CF
# 9   Final        Internazionale    1-0                SL Benfica
# 10  Final        Real Madrid CF    2-1         Partizan Belgrade
# 11  Final             Celtic FC    2-1            Internazionale
# 12  Final  Manchester United FC   1-1                 SL Benfica
# ...

# %%
df["ET"]=df["ET"].apply(lambda x:x.split("(")[0])

# %%
df["P"] = df["P"].apply(lambda x:x.split("(")[0])

# %%
df
# Out:
#     Round                 Team 1    FT                     Team 2    ET     P  \
# 0   Final        Real Madrid CF    4-3               Stade Reims    0-0   0-0
# 1   Final        Real Madrid CF    2-0            ACF Fiorentina    0-0   0-0
# 2   Final        Real Madrid CF   2-2                   AC Milan   3-2    0-0
# 3   Final        Real Madrid CF    2-0               Stade Reims    0-0   0-0
# 4   Final        Real Madrid CF    7-3  Frankfurter SG Eintracht    0-0   0-0
# 5   Final            SL Benfica    3-2              FC Barcelona    0-0   0-0
# 6   Final            SL Benfica    5-3            Real Madrid CF    0-0   0-0
# 7   Final              AC Milan    2-1                SL Benfica    0-0   0-0
# 8   Final        Internazionale    3-1            Real Madrid CF    0-0   0-0
# 9   Final        Internazionale    1-0                SL Benfica    0-0   0-0
# 10  Final        Real Madrid CF    2-1         Partizan Belgrade    0-0   0-0
# ...

# %%
df["Team1ET"] = df["ET"].apply(lambda x:x.split("-")[0])

# %%
df["Team2ET"] = df["ET"].apply(lambda x:x.split("-")[1])

# %%
df["Team1P"] = df["P"].apply(lambda x:x.split("-")[0])

# %%
df["Team2P"] = df["P"].apply(lambda x:x.split("-")[1])

# %%
df
# Out:
#     Round                 Team 1    FT                     Team 2    ET     P  \
# 0   Final        Real Madrid CF    4-3               Stade Reims    0-0   0-0
# 1   Final        Real Madrid CF    2-0            ACF Fiorentina    0-0   0-0
# 2   Final        Real Madrid CF   2-2                   AC Milan   3-2    0-0
# 3   Final        Real Madrid CF    2-0               Stade Reims    0-0   0-0
# 4   Final        Real Madrid CF    7-3  Frankfurter SG Eintracht    0-0   0-0
# 5   Final            SL Benfica    3-2              FC Barcelona    0-0   0-0
# 6   Final            SL Benfica    5-3            Real Madrid CF    0-0   0-0
# 7   Final              AC Milan    2-1                SL Benfica    0-0   0-0
# 8   Final        Internazionale    3-1            Real Madrid CF    0-0   0-0
# 9   Final        Internazionale    1-0                SL Benfica    0-0   0-0
# 10  Final        Real Madrid CF    2-1         Partizan Belgrade    0-0   0-0
# ...

# %%
df = df.astype({'Team1FT':'int64','Team2FT':'int64','Team1ET':'int64','Team2ET':'int64','Team1P':'int64','Team2P':'int64'},errors = 'ignore')

# %%
df
# Out:
#     Round                 Team 1    FT                     Team 2    ET     P  \
# 0   Final        Real Madrid CF    4-3               Stade Reims    0-0   0-0
# 1   Final        Real Madrid CF    2-0            ACF Fiorentina    0-0   0-0
# 2   Final        Real Madrid CF   2-2                   AC Milan   3-2    0-0
# 3   Final        Real Madrid CF    2-0               Stade Reims    0-0   0-0
# 4   Final        Real Madrid CF    7-3  Frankfurter SG Eintracht    0-0   0-0
# 5   Final            SL Benfica    3-2              FC Barcelona    0-0   0-0
# 6   Final            SL Benfica    5-3            Real Madrid CF    0-0   0-0
# 7   Final              AC Milan    2-1                SL Benfica    0-0   0-0
# 8   Final        Internazionale    3-1            Real Madrid CF    0-0   0-0
# 9   Final        Internazionale    1-0                SL Benfica    0-0   0-0
# 10  Final        Real Madrid CF    2-1         Partizan Belgrade    0-0   0-0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Round    61 non-null     object
#  1   Team 1   61 non-null     object
#  2   FT       61 non-null     object
#  3   Team 2   61 non-null     object
#  4   ET       61 non-null     object
#  5   P        61 non-null     object
#  6   Year     61 non-null     int64
#  7   Team1FT  61 non-null     int64
#  8   Team2FT  61 non-null     int64
#  9   Team1ET  61 non-null     int64
#  10  Team2ET  61 non-null     int64
#  11  Team1P   61 non-null     int64
#  12  Team2P   61 non-null     int64
# dtypes: int64(7), object(6)
# memory usage: 6.3+ KB

# %%
df["Average"] = df["Team1FT"] + df["Team1ET"] + df["Team1P"]-df["Team2FT"] - df["Team2ET"] - df["Team2P"]

# %%
df = df.drop(["Total_Gol1","Total_Gol2"],axis=1)

# %%
df
# Out:
#     Round                 Team 1    FT                     Team 2    ET     P  \
# 0   Final        Real Madrid CF    4-3               Stade Reims    0-0   0-0
# 1   Final        Real Madrid CF    2-0            ACF Fiorentina    0-0   0-0
# 2   Final        Real Madrid CF   2-2                   AC Milan   3-2    0-0
# 3   Final        Real Madrid CF    2-0               Stade Reims    0-0   0-0
# 4   Final        Real Madrid CF    7-3  Frankfurter SG Eintracht    0-0   0-0
# 5   Final            SL Benfica    3-2              FC Barcelona    0-0   0-0
# 6   Final            SL Benfica    5-3            Real Madrid CF    0-0   0-0
# 7   Final              AC Milan    2-1                SL Benfica    0-0   0-0
# 8   Final        Internazionale    3-1            Real Madrid CF    0-0   0-0
# 9   Final        Internazionale    1-0                SL Benfica    0-0   0-0
# 10  Final        Real Madrid CF    2-1         Partizan Belgrade    0-0   0-0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Round    61 non-null     object
#  1   Team 1   61 non-null     object
#  2   FT       61 non-null     object
#  3   Team 2   61 non-null     object
#  4   ET       61 non-null     object
#  5   P        61 non-null     object
#  6   Year     61 non-null     int64
#  7   Team1FT  61 non-null     int64
#  8   Team2FT  61 non-null     int64
#  9   Team1ET  61 non-null     int64
#  10  Team2ET  61 non-null     int64
#  11  Team1P   61 non-null     int64
#  12  Team2P   61 non-null     int64
#  13  Average  61 non-null     int64
# dtypes: int64(8), object(6)
# memory usage: 6.8+ KB

# %%
df.loc[df['Average']>0, 'Champion'] = df['Team 1']

# %%
df.loc[df['Average']<0, 'Champion'] = df['Team 2']

# %%
df
# Out:
#     Round                 Team 1    FT                     Team 2    ET     P  \
# 0   Final        Real Madrid CF    4-3               Stade Reims    0-0   0-0
# 1   Final        Real Madrid CF    2-0            ACF Fiorentina    0-0   0-0
# 2   Final        Real Madrid CF   2-2                   AC Milan   3-2    0-0
# 3   Final        Real Madrid CF    2-0               Stade Reims    0-0   0-0
# 4   Final        Real Madrid CF    7-3  Frankfurter SG Eintracht    0-0   0-0
# 5   Final            SL Benfica    3-2              FC Barcelona    0-0   0-0
# 6   Final            SL Benfica    5-3            Real Madrid CF    0-0   0-0
# 7   Final              AC Milan    2-1                SL Benfica    0-0   0-0
# 8   Final        Internazionale    3-1            Real Madrid CF    0-0   0-0
# 9   Final        Internazionale    1-0                SL Benfica    0-0   0-0
# 10  Final        Real Madrid CF    2-1         Partizan Belgrade    0-0   0-0
# ...

# %%
final = df[["Year","Team 1","Team 2","FT","Champion"]]

# %%
final
# Out:
#     Year                 Team 1                     Team 2    FT  \
# 0   1956        Real Madrid CF                Stade Reims    4-3
# 1   1957        Real Madrid CF             ACF Fiorentina    2-0
# 2   1958        Real Madrid CF                   AC Milan   2-2
# 3   1959        Real Madrid CF                Stade Reims    2-0
# 4   1960        Real Madrid CF   Frankfurter SG Eintracht    7-3
# 5   1961            SL Benfica               FC Barcelona    3-2
# 6   1962            SL Benfica             Real Madrid CF    5-3
# 7   1963              AC Milan                 SL Benfica    2-1
# 8   1964        Internazionale             Real Madrid CF    3-1
# 9   1965        Internazionale                 SL Benfica    1-0
# 10  1966        Real Madrid CF          Partizan Belgrade    2-1
# 11  1967             Celtic FC             Internazionale    2-1
# 12  1968  Manchester United FC                 SL Benfica   1-1
# ...

# %%
final["Champion"].value_counts()
# Out:
# Real Madrid CF           11
# AC Milan                  7
# FC Barcelona              5
# Bayern München            5
# Liverpool FC              5
# AFC Ajax                  4
# Internazionale            3
# Manchester United FC      3
# Nottingham Forest FC      2
# Juventus                  2
# FC Porto                  2
# SL Benfica                2
# Olympique Marseille       1
# Crvena Zvezda             1
# Feyenoord Rotterdam       1
# Celtic FC                 1
# Hamburger SV              1
# PSV Eindhoven             1
# Borussia Dortmund         1
# Steaua Bucuresti          1
# Aston Villa FC            1
# Chelsea FC                1
# Name: Champion, dtype: int64
